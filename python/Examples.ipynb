# %%
import FundingConsultation

# %%
quantitative_data = FundingConsultation.get_quantitative_data()
qualitative_data = FundingConsultation.get_qualitative_data()

# %%
# loading the mappings of index numbers to answers for programmatic access
# this command merges the info in ../data/value_labels_dat.yml and ../data/value_labels.yml
index_interpretations = FundingConsultation.get_index_interpretations()

# %%
# show all the index interpretations - we need them when slicing data
index_interpretations
# Out:
# {'work_life': {'class': 'ordered',
#   '1': 'Nee',
#   '2': 'Ja, in kleine mate',
#   '3': 'Ja, in grote mate'},
#  'versie': {'class': 'factor', '1': '1', '2': '2', '3': '3'},
#  'age': {'class': 'ordered',
#   '1': 'Tot en met 30',
#   '2': '31-40',
#   '3': '41-50',
#   '4': '51-60',
#   '5': '61-70',
#   '6': '71 plus'},
#  'quit': {'class': 'ordered',
#   '1': 'Nee',
#   '2': 'Ja, in het verleden',
#   '3': 'Ja, ik overweeg de wetenschap te verlaten'},
#  'major_changes': {'class': 'ordered',
#   '1': 'Geen wijzigingen',
#   '2': 'Kleine wijzigingen',
#   '3': 'Grote wijzigingen'},
#  'grant_no': {'class': 'ordered', '0': 'Nee', '1': 'Ja'},
#  'grant_pers_nl': {'class': 'ordered',
#   '0': 'Nee',
#   '1': 'Ja, een persoonlijke beurs in Nederland'},
#  'grant_pers_foreign': {'class': 'ordered',
#   '0': 'Nee',
#   '1': 'Ja, een persoonlijke beurs in het buitenland, of een Europese beurs'},
#  'grant_consortium': {'class': 'ordered',
#   '0': 'Nee',
#   '1': 'Ja, als leider van een team of consortium'},
#  'grant_faculty': {'class': 'ordered',
#   '0': 'Nee',
#   '1': 'Ja, een onderzoeksvoorstel voor een faculteit'},
#  'grant_university': {'class': 'ordered',
#   '0': 'Nee',
#   '1': 'Ja, een onderzoeksvoorstel voor een universiteit'},
#  'grant_foundation': {'class': 'ordered',
#   '0': 'Nee',
#   '1': 'Ja, een onderzoeksvoorstel voor een stichting'},
#  'grant_private': {'class': 'ordered',
#   '0': 'Nee',
#   '1': 'Ja, een onderzoeksvoorstel voor een bedrijf of overheid'},
#  'nogrant_want': {'class': 'ordered',
#   '0': 'Nee',
#   '1': 'Ik wil dat niet doen.'},
#  'nogrant_necessary': {'class': 'ordered',
#   '0': 'Nee',
#   '1': 'Ik heb dat niet nodig. Ik hoef dat niet te doen van mijn leidinggevende.'},
#  'nogrant_early': {'class': 'ordered',
#   '0': 'Nee',
#   '1': 'Ik vind het nog te vroeg in mijn carriere om dat te doen.'},
#  'nogrant_education': {'class': 'ordered',
#   '0': 'Nee',
#   '1': 'Ik vind onderwijs belangrijker om mijn tijd in te steken.'},
#  'nogrant_time': {'class': 'ordered',
#   '0': 'Nee',
#   '1': 'Ik heb er geen tijd voor.'},
#  'nogrant_waste': {'class': 'ordered',
#   '0': 'Nee',
#   '1': 'Ik ben bang dat het zonde van mijn tijd is.'},
#  'successful_applications': {'class': 'ordered',
#   '1': 'Nee',
#   '2': 'Ja, minder dan 10% van mijn aanvragen',
#   '3': 'Ja, 10-20% van mijn aanvragen',
#   '4': 'Ja, 20-30% van mijn aanvragen',
#   '5': 'Ja, meer dan 30% van mijn aanvragen'},
#  'body_nwo': {'class': 'ordered', '0': 'Nee', '1': 'NWO'},
#  'body_university': {'class': 'ordered',
#   '0': 'Nee',
#   '1': 'Binnen mijn eigen universiteit/faculteit'},
#  'body_foreign': {'class': 'ordered',
#   '0': 'Nee',
#   '1': 'Een Europese of andere buitenlandse financier'},
#  'body_award': {'class': 'ordered', '0': 'Nee', '1': 'Een award-commissie'},
#  'body_none': {'class': 'ordered', '0': 'Nee', '1': 'Nee'},
#  'rol_supervisor': {'class': 'ordered',
#   '1': 'Geen rol',
#   '2': 'Een kleine rol',
#   '3': 'Een redelijk grote rol',
#   '4': 'Een zeer grote rol'},
#  'rol_head': {'class': 'ordered',
#   '1': 'Geen rol',
#   '2': 'Een kleine rol',
#   '3': 'Een redelijk grote rol',
#   '4': 'Een zeer grote rol'},
#  'rol_dean': {'class': 'ordered',
#   '1': 'Geen rol',
#   '2': 'Een kleine rol',
#   '3': 'Een redelijk grote rol',
#   '4': 'Een zeer grote rol'},
#  'rol_colleagues': {'class': 'ordered',
#   '1': 'Geen rol',
#   '2': 'Een kleine rol',
#   '3': 'Een redelijk grote rol',
#   '4': 'Een zeer grote rol'},
#  'rol_nwo': {'class': 'ordered',
#   '1': 'Geen rol',
#   '2': 'Een kleine rol',
#   '3': 'Een redelijk grote rol',
#   '4': 'Een zeer grote rol'},
#  'rol_ocw': {'class': 'ordered',
#   '1': 'Geen rol',
#   '2': 'Een kleine rol',
#   '3': 'Een redelijk grote rol',
#   '4': 'Een zeer grote rol'},
#  'rol_mentor': {'class': 'ordered',
#   '1': 'Geen rol',
#   '2': 'Een kleine rol',
#   '3': 'Een redelijk grote rol',
#   '4': 'Een zeer grote rol'},
#  'carreer_success': {'class': 'ordered', '1': 'Nee', '2': 'Ja'},
#  'need_no': {'class': 'ordered',
#   '0': 'Nee',
#   '1': 'Niets, ik ben nu waar ik qua carrièrepad wil zijn'},
#  'need_security': {'class': 'ordered',
#   '0': 'Nee',
#   '1': 'Een beurs voor een aantal jaren om mijn eigen baan veilig te stellen'},
#  'need_team': {'class': 'ordered',
#   '0': 'Nee',
#   '1': 'Een beurs om mijn team uit te breiden'},
#  'need_freedom': {'class': 'ordered',
#   '0': 'Nee',
#   '1': 'Een beurs om wat meer vrijheid te hebben mijn eigen tijd in te delen'},
#  'need_equipment': {'class': 'ordered',
#   '0': 'Nee',
#   '1': 'Een beurs om apparatuur of infrastructuur aan te schaffen.'},
#  'award_fair': {'class': 'ordered',
#   '1': 'Helemaal niet mee eens',
#   '2': 'Niet mee eens',
#   '3': 'Neutraal',
#   '4': 'Mee eens',
#   '5': 'Helemaal mee eens'},
#  'award_lottery': {'class': 'ordered',
#   '1': 'Helemaal niet mee eens',
#   '2': 'Niet mee eens',
#   '3': 'Neutraal',
#   '4': 'Mee eens',
#   '5': 'Helemaal mee eens'},
#  'award_time': {'class': 'ordered',
#   '1': 'Helemaal niet mee eens',
#   '2': 'Niet mee eens',
#   '3': 'Neutraal',
#   '4': 'Mee eens',
#   '5': 'Helemaal mee eens'},
#  'award_bandwagon': {'class': 'ordered',
#   '1': 'Helemaal niet mee eens',
#   '2': 'Niet mee eens',
#   '3': 'Neutraal',
#   '4': 'Mee eens',
#   '5': 'Helemaal mee eens'},
#  'who_researcher': {'class': 'ordered',
#   '1': 'Geen invloed',
#   '2': 'Neutraal',
#   '3': 'Wat invloed',
#   '4': 'Veel invloed'},
#  'who_manager': {'class': 'ordered',
#   '1': 'Geen invloed',
#   '2': 'Neutraal',
#   '3': 'Wat invloed',
#   '4': 'Veel invloed'},
#  'who_university': {'class': 'ordered',
#   '1': 'Geen invloed',
#   '2': 'Neutraal',
#   '3': 'Wat invloed',
#   '4': 'Veel invloed'},
#  'who_committee': {'class': 'ordered',
#   '1': 'Geen invloed',
#   '2': 'Neutraal',
#   '3': 'Wat invloed',
#   '4': 'Veel invloed'},
#  'who_government': {'class': 'ordered',
#   '1': 'Geen invloed',
#   '2': 'Neutraal',
#   '3': 'Wat invloed',
#   '4': 'Veel invloed'},
#  'who_society': {'class': 'ordered',
#   '1': 'Geen invloed',
#   '2': 'Neutraal',
#   '3': 'Wat invloed',
#   '4': 'Veel invloed'},
#  'co_private': {'class': 'ordered',
#   '1': 'Helemaal niet mee eens',
#   '2': 'Niet mee eens',
#   '3': 'Neutraal',
#   '4': 'Mee eens',
#   '5': 'Helemaal mee eens'},
#  'co_connections': {'class': 'ordered',
#   '1': 'Helemaal niet mee eens',
#   '2': 'Niet mee eens',
#   '3': 'Neutraal',
#   '4': 'Mee eens',
#   '5': 'Helemaal mee eens'},
#  'co_irrelevant': {'class': 'ordered',
#   '1': 'Helemaal niet mee eens',
#   '2': 'Niet mee eens',
#   '3': 'Neutraal',
#   '4': 'Mee eens',
#   '5': 'Helemaal mee eens'},
#  'time_research': {'class': 'ordered',
#   '1': 'Geen tijd',
#   '2': 'Bijna geen tijd',
#   '3': 'Veel tijd',
#   '4': 'Bijna al mijn tijd'},
#  'time_education': {'class': 'ordered',
#   '1': 'Geen tijd',
#   '2': 'Bijna geen tijd',
#   '3': 'Veel tijd',
#   '4': 'Bijna al mijn tijd'},
#  'time_phds': {'class': 'ordered',
#   '1': 'Geen tijd',
#   '2': 'Bijna geen tijd',
#   '3': 'Veel tijd',
#   '4': 'Bijna al mijn tijd'},
#  'time_management_low': {'class': 'ordered',
#   '1': 'Geen tijd',
#   '2': 'Bijna geen tijd',
#   '3': 'Veel tijd',
#   '4': 'Bijna al mijn tijd'},
#  'time_management_hi': {'class': 'ordered',
#   '1': 'Geen tijd',
#   '2': 'Bijna geen tijd',
#   '3': 'Veel tijd',
#   '4': 'Bijna al mijn tijd'},
#  'time_service': {'class': 'ordered',
#   '1': 'Geen tijd',
#   '2': 'Bijna geen tijd',
#   '3': 'Veel tijd',
#   '4': 'Bijna al mijn tijd'},
#  'time_admin': {'class': 'ordered',
#   '1': 'Geen tijd',
#   '2': 'Bijna geen tijd',
#   '3': 'Veel tijd',
#   '4': 'Bijna al mijn tijd'},
#  'time_involvement': {'class': 'ordered',
#   '1': 'Geen tijd',
#   '2': 'Bijna geen tijd',
#   '3': 'Veel tijd',
#   '4': 'Bijna al mijn tijd'},
#  'time_patients': {'class': 'ordered',
#   '1': 'Geen tijd',
#   '2': 'Bijna geen tijd',
#   '3': 'Veel tijd',
#   '4': 'Bijna al mijn tijd'},
#  'review_info': {'class': 'ordered',
#   '1': 'Helemaal niet mee eens',
#   '2': 'Niet mee eens',
#   '3': 'Neutraal',
#   '4': 'Mee eens',
#   '5': 'Helemaal mee eens'},
#  'review_confidence': {'class': 'ordered',
#   '1': 'Helemaal niet mee eens',
#   '2': 'Niet mee eens',
#   '3': 'Neutraal',
#   '4': 'Mee eens',
#   '5': 'Helemaal mee eens'},
#  'review_informative': {'class': 'ordered',
#   '1': 'Helemaal niet mee eens',
#   '2': 'Niet mee eens',
#   '3': 'Neutraal',
#   '4': 'Mee eens',
#   '5': 'Helemaal mee eens'},
#  'review_more': {'class': 'ordered',
#   '1': 'Helemaal niet mee eens',
#   '2': 'Niet mee eens',
#   '3': 'Neutraal',
#   '4': 'Mee eens',
#   '5': 'Helemaal mee eens'},
#  'review_government': {'class': 'ordered',
#   '1': 'Helemaal niet mee eens',
#   '2': 'Niet mee eens',
#   '3': 'Neutraal',
#   '4': 'Mee eens',
#   '5': 'Helemaal mee eens'},
#  'sex': {'class': 'factor', '1': 'Man', '2': 'Vrouw'},
#  'language': {'class': 'factor', '1': 'en', '2': 'nl'},
#  'discipline': {'class': 'factor',
#   '1': 'Humanities and social sciences',
#   '2': 'Beta and medicine',
#   '3': 'Economy, business, law'},
#  'pos5': {'class': 'factor',
#   '1': 'Student-PhD-Postdoc-OA = ECR',
#   '2': 'Assistant/associate prof/UD (temporary contract)',
#   '3': 'Assistant, associate (permanent)',
#   '4': 'Hoogleraar/professor',
#   '5': 'Other'},
#  'pos9': {'class': 'factor',
#   '1': 'Student/Onderzoeksassistent/junior onderzoeker',
#   '2': 'PhD',
#   '3': 'Postdoc',
#   '4': 'Assistant prof/UD (temporary)',
#   '5': 'Assistant prof/UD (tenured)',
#   '6': 'Associate prof/UHD',
#   '7': 'Prof / Hoogleraar',
#   '8': 'Anders'},
#  'institution': {'class': 'factor',
#   '1': 'Academisch Medisch Centrum',
#   '2': 'Erasmus MC',
#   '3': 'Erasmus Universiteit Rotterdam',
#   '4': 'Leids Universitair Medisch Centrum',
#   '5': 'Radboud Universiteit Nijmegen',
#   '6': 'Rijksuniversiteit Groningen',
#   '7': 'Technische Universiteit Delft',
#   '8': 'Technische Universiteit Eindhoven',
#   '9': 'Universiteit Leiden',
#   '10': 'Universiteit Maastricht',
#   '11': 'Universiteit Twente',
#   '12': 'Universiteit Utrecht',
#   '13': 'Universiteit van Amsterdam',
#   '14': 'Universiteit van Tilburg',
#   '15': 'Vrije Universiteit Amsterdam',
#   '16': 'Vrije Universiteit medisch centrum',
#   '17': 'Wageningen Universiteit en Research',
#   '18': 'Ik werk niet voor een universiteit',
#   '19': 'Overig'}}

# %% [markdown]
# To select quantitative data on specific conditions, specify a dictionary with each of the conditions (column names) and corresponding values to select on. A dictionary is specified between {accolades}. Each entry in the dictionary contains of a key (the column name, between 'quotes'), a ':' character, and a list between \[square brackets\] of the values you want to select on (which can just be specified as numbers)

# %%
# for example, say we want people who for 'major_changes' wanted 'kleine wijzigingen' or 'grote wijzigingen',
# and who are in the youngest age category.
# We can then turns this in a dictionary of conditions as follows:
conditions = {'major_changes': [2, 3], 'age': [1]}

# %% [markdown]
# The `select_from_quantitative_data()` function has two parameters: the first is the data frame from which a selection should be made, the second a dictionary of conditions to select on.

# %%
# we use the above-specified conditions to make a selection from the overall quantitative data
wants_changes_and_is_young = FundingConsultation.select_from_quantitative_data(quantitative_data, conditions)

# display the data frame
wants_changes_and_is_young
# Out:
#       ktversie  kt_slider_personal_senior  kt_slider_team  \
# 2          5.0                   0.011429        0.120000
# 12         7.0                   0.000000        0.000000
# 18         1.0                   0.173333        0.200000
# 24         2.0                   0.142857        0.142857
# 125        9.0                   0.000000        0.000000
# ...        ...                        ...             ...
# 2051       2.0                   0.120000        0.202857
# 2113       5.0                   0.150000        0.150000
# 2125       4.0                   0.066667        0.166667
# 2136       8.0                   0.066667        0.066667
# 2151       8.0                   0.250000        0.150000
#
#       kt_slider_personal_ecr  kt_slider_thematic  kt_slider_thematic_co  \
# 2                   0.420000            0.266667               0.054444
# 12                  0.250000            0.054545               0.036364
# 18                  0.200000            0.187500               0.062500
# 24                  0.285714            0.083333               0.083333
# 125                 0.288571            0.343333               0.000000
# ...                      ...                 ...                    ...
# 2051                0.200000            0.128889               0.132222
# 2113                0.150000            0.054545               0.027273
# 2125                0.066667            0.150000               0.150000
# 2136                0.133333            0.062500               0.062500
# 2151                0.400000            0.136364               0.090909
#
#       kt_slider_small_first  kt_slider_small_second  kt_slider_award  \
# 2                  0.208571                0.008571             0.06
# 12                 1.000000                0.150000             0.00
# 18                 0.293333                0.000000             0.40
# 24                 0.428571                0.085714             0.00
# 125                0.845714                0.000000             0.00
# ...                     ...                     ...              ...
# 2051               0.122857                0.000000             0.00
# 2113               0.250000                0.150000             0.10
# 2125               0.333333                0.200000             0.10
# 2136               0.400000                0.133333             0.10
# 2151               0.125000                0.250000             0.10
#
#       kt_slider_first_ecr  ...   kt_team  kt_personal_ecr  kt_thematic  \
# 2                0.405714  ...  0.046667         0.163333     0.266667
# 12               0.100000  ...  0.000000         0.090909     0.054545
# 18               0.200000  ...  0.075000         0.075000     0.187500
# 24               0.571429  ...  0.055556         0.111111     0.083333
# 125              0.548571  ...  0.000000         0.112222     0.343333
# ...                   ...  ...       ...              ...          ...
# 2051             0.268571  ...  0.078889         0.077778     0.128889
# 2113             0.375000  ...  0.054545         0.054545     0.054545
# 2125             0.466667  ...  0.062500         0.025000     0.150000
# 2136             0.533333  ...  0.025000         0.050000     0.062500
# 2151             0.400000  ...  0.054545         0.145455     0.136364
#
#       kt_thematic_co  kt_small_first  kt_small_second  kt_award kt_first_ecr  \
# 2           0.054444        0.081111         0.003333  0.003333     0.157778
# 12          0.036364        0.363636         0.054545  0.000000     0.036364
# 18          0.062500        0.110000         0.000000  0.050000     0.075000
# 24          0.083333        0.166667         0.033333  0.000000     0.222222
# 125         0.000000        0.328889         0.000000  0.000000     0.213333
# ...              ...             ...              ...       ...          ...
# 2051        0.132222        0.047778         0.000000  0.000000     0.104444
# 2113        0.027273        0.090909         0.054545  0.009091     0.136364
# 2125        0.150000        0.125000         0.075000  0.012500     0.175000
# 2136        0.062500        0.150000         0.050000  0.012500     0.200000
# 2151        0.090909        0.045455         0.090909  0.009091     0.145455
#
#       kt_rolling_ecr  kt_rolling_senior
# 2           0.090000           0.078889
# 12          0.181818           0.181818
# 18          0.150000           0.150000
# 24          0.111111           0.077778
# 125         0.000000           0.000000
# ...              ...                ...
# 2051        0.166667           0.163333
# 2113        0.272727           0.181818
# 2125        0.150000           0.050000
# 2136        0.237500           0.125000
# 2151        0.100000           0.090909
#
# [63 rows x 115 columns]

# %% [markdown]
# With the `match_to_qualitative_responses()` function, we can look up the qualitative responses for people represented in a particular data frame. The first parameter specifies the data frame for which corresponding answers should be found; the second parameter specifies the data frame with all qualitative answers

# %%
# Let's for example do that with the selection we just made (young people wanting change)
wants_changes_and_is_young_qual = FundingConsultation.match_to_qualitative_responses(wants_changes_and_is_young, qualitative_data)

# display the data frame
wants_changes_and_is_young_qual
# Out:
#         id                                               mkt1  \
# 2        3                                                NaN
# 12      13                                                NaN
# 18      19  While a competitive element is needed in my vi...
# 24      25                                                NaN
# 125    126  Deze blijven belangrijk om de excellente onder...
# ...    ...                                                ...
# 2052  2066                                                NaN
# 2113  2128                                                NaN
# 2125  2140                                                NaN
# 2136  2151                                                NaN
# 2151  2166                                                NaN
#
#                                                    mkt2  \
# 2                                                   NaN
# 12                                                  NaN
# 18                                       Same as above.
# 24                                                  NaN
# 125   Hoewel het idee is dat een consortium van onde...
# ...                                                 ...
# 2052                                                NaN
# 2113                                                NaN
# 2125                                                NaN
# 2136                                                NaN
# 2151                                                NaN
#
#                                                    mkt3  \
# 2                                                   NaN
# 12                                                  NaN
# 18    If we want to help new scholars establish thei...
# 24                                                  NaN
# 125   Deze blijven belangrijk om de excellente onder...
# ...                                                 ...
# 2052                                                NaN
# 2113                                                NaN
# 2125                                                NaN
# 2136                                                NaN
# 2151                                                NaN
#
#                                                    mkt4  \
# 2                                                   NaN
# 12                                        Team science.
# 18    I tend to be a bit more skeptical of thematic ...
# 24                                                  NaN
# 125   Vooral voor fundamenteel, nieuwsgierigheidsged...
# ...                                                 ...
# 2052                                                NaN
# 2113                                                NaN
# 2125                                                NaN
# 2136                                                NaN
# 2151                                                NaN
#
#                                                    mkt5  \
# 2                                                   NaN
# 12                                                  NaN
# 18    Having to co-fund is always a drag if you are ...
# 24                                                  NaN
# 125   Dit betreft veelal de projecten met een meer d...
# ...                                                 ...
# 2052                                                NaN
# 2113                                                NaN
# 2125                                                NaN
# 2136                                                NaN
# 2151                                                NaN
#
#                                                    mkt6  \
# 2                                                   NaN
# 12                                                  NaN
# 18    I find this to be very important in allowing s...
# 24                                                  NaN
# 125   Ook hier zijn de subsidies te klein om onderzo...
# ...                                                 ...
# 2052                                                NaN
# 2113                                                NaN
# 2125                                                NaN
# 2136                                                NaN
# 2151                                                NaN
#
#                                                    mkt7  \
# 2                                                   NaN
# 12                                                  NaN
# 18                                                  NaN
# 24                                                  NaN
# 125   Ook hier zijn de subsidies te klein om onderzo...
# ...                                                 ...
# 2052                                                NaN
# 2113                                                NaN
# 2125                                                NaN
# 2136                                                NaN
# 2151                                                NaN
#
#                                                    mkt8  \
# 2                                                   NaN
# 12                                                  NaN
# 18    I personally think that if you had a major ach...
# 24                                                  NaN
# 125   Geld voor prijzen is vooral bedoeld als een so...
# ...                                                 ...
# 2052                                                NaN
# 2113                                                NaN
# 2125                                                NaN
# 2136                                                NaN
# 2151                                                NaN
#
#                                                    mkt9  ... grant_other  \
# 2     dit zijn belachelijke keuzes, er zijn geen alt...  ...         NaN
# 12                                                  NaN  ...         NaN
# 18    Important to give younger colleagues the possi...  ...         NaN
# 24                                                  NaN  ...         NaN
# 125   Het is belangrijk om voldoende mogelijkheden t...  ...         NaN
# ...                                                 ...  ...         ...
# 2052                                                NaN  ...         NaN
# 2113  De competitie is inmiddels het doel voorbij ge...  ...         NaN
# 2125                                                NaN  ...         NaN
# 2136                                                NaN  ...         NaN
# 2151                                                NaN  ...         NaN
#
#      nogrant_other              decision_open  \
# 2              NaN                        NaN
# 12             NaN                        NaN
# 18             NaN                        NaN
# 24             NaN                        NaN
# 125            NaN  Nederlandse hartstichting
# ...            ...                        ...
# 2052           NaN                        NaN
# 2113           NaN                        NaN
# 2125           NaN                        NaN
# 2136           NaN                        NaN
# 2151           NaN                        NaN
#
#                                            idea_science  \
# 2                                                   NaN
# 12                    More structural research funding.
# 18    Less competition, more time to think and devel...
# 24                                                  NaN
# 125   Op onze universiteit is de onderwijsdruk erg h...
# ...                                                 ...
# 2052                                                NaN
# 2113  Meer tijd om te lezen en na te denken, minder ...
# 2125                                                NaN
# 2136                                                NaN
# 2151                                                NaN
#
#                                            idea_society  \
# 2                                             ja genoeg
# 12    Thematic calls for research that addresses soc...
# 18    Dedicated professionals who organize and plan ...
# 24                                                  NaN
# 125                                                 NaN
# ...                                                 ...
# 2052                                                NaN
# 2113  Meer contacten faciliteren, minder dwang om je...
# 2125                                                NaN
# 2136                                                NaN
# 2151                                                NaN
#
#                                         carreer_explain  \
# 2                                                   NaN
# 12    Getting an ERC consolidator grant led to a ful...
# 18    Getting a grant got me a permanent position an...
# 24                                                  NaN
# 125   Het binnenhalen van persoonlijke subsidie was ...
# ...                                                 ...
# 2052                                                NaN
# 2113  Ik heb geluk gehad met een stom Europees proje...
# 2125                                                NaN
# 2136                                                NaN
# 2151                                                NaN
#
#                                              need_other  \
# 2                                     een ander systeem
# 12                                                  NaN
# 18                                                  NaN
# 24                                                  NaN
# 125   meerdere beurzen om mijn eigen onderzoekslijn ...
# ...                                                 ...
# 2052                                                NaN
# 2113                                                NaN
# 2125                                                NaN
# 2136                                                NaN
# 2151                                                NaN
#
#                                                 opinion  \
# 2     Dat er hier dilemmas en keuzes worden voorgeho...
# 12    I would like to see a study of the impact of N...
# 18                                                  NaN
# 24                                                  NaN
# 125                                                 NaN
# ...                                                 ...
# 2052                                                NaN
# 2113                                                NaN
# 2125                                                NaN
# 2136                                                NaN
# 2151                                                NaN
#
#                                         review_positive  \
# 2                                   dat deze plaatsvind
# 12                          ease of use/good interface.
# 18                                                  NaN
# 24                                                  NaN
# 125   voldoende mogelijkheid om uitleg over keuzes t...
# ...                                                 ...
# 2052                                                NaN
# 2113                                                NaN
# 2125                                                NaN
# 2136                                                NaN
# 2151                                                NaN
#
#                                         review_negative
# 2     de keuzes zij te veel voorgekauwd, er bestaan ...
# 12                               nothing comes to mind.
# 18                                                  NaN
# 24                                                  NaN
# 125                                                 NaN
# ...                                                 ...
# 2052                                                NaN
# 2113                                                NaN
# 2125                                                NaN
# 2136                                                NaN
# 2151                                                NaN
#
# [63 rows x 29 columns]

# %% [markdown]
# This is not so readable, it may be easier to export the non-empty (i.e. non-NaN) answers of any columns you are interested in to a text file. For this, the `export_qualitative_responses()` function can be used.
# The first parameter specifies the data frame from which the export should be made, the second the column of interest, and the third a user-specified file name. The file will be exported to the `text/' folder.

# %%
# for example, export what the young people wanting change would like to change
# (see the Variablelen_DJA_shortlabels.csv for the column name - in this case, it would be 'which_changes')

FundingConsultation.export_qualitative_responses(wants_changes_and_is_young_qual, 'which_changes', 'changes_demanded_young.txt')
